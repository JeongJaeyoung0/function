# %%
def sum(a, b):
    print('a+b의 결과는 :', a+b)

# %%
def product():
    a = int(input())
    b = int(input())
    print('a*b의 결과는 :', a*b)

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result
        
    def sub(self, num):
        self.result -= num
        return self.result
